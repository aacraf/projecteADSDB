# %%
# !pip install duckdb

import duckdb
import pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting duckdb
#   Downloading duckdb-0.5.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      |████████████████████████████████| 16.4 MB 4.8 MB/s
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.7/dist-packages (from duckdb) (1.21.6)
# Installing collected packages: duckdb
# Successfully installed duckdb-0.5.1

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#con = duckdb.connect(database='/content/drive/MyDrive/projecteADSDB/explotation/explotation.duckdb', read_only=False)

con = duckdb.connect(database='./explotation/explotation.duckdb', read_only=False)

df_governance = pd.read_sql("SELECT * FROM Governance_Data", con)

# %% [markdown]
# # melt the datarame

# %%
# provisional treatment
df_governance.drop_duplicates(inplace=True)

# %%
aruba = df_governance[df_governance["Country Code"] == 'ABW']
aruba.head(20)
# Out:
#                                            Country Name Country Code  \
# 230                                               Aruba          ABW
# 231                                               Aruba          ABW
# 232                                               Aruba          ABW
# 233                                               Aruba          ABW
# 234                                               Aruba          ABW
# 235                                               Aruba          ABW
# 236                                               Aruba          ABW
# 237                                               Aruba          ABW
# 238                                               Aruba          ABW
# 239                                               Aruba          ABW
# 240                                               Aruba          ABW
# 241                                               Aruba          ABW
# 242                                               Aruba          ABW
# 243                                               Aruba          ABW
# 244                                               Aruba          ABW
# 245                                               Aruba          ABW
# 246                                               Aruba          ABW
# 247                                               Aruba          ABW
# 4893                                        Afghanistan          ABW
# 4894  Data from database: Worldwide Governance Indic...          ABW
#
#                                             Series Name Series Code  \
# 230                     Control of Corruption: Estimate      CC.EST
# 231            Control of Corruption: Number of Sources   CC.NO.SRC
# 232               Control of Corruption: Standard Error  CC.STD.ERR
# 233                  Government Effectiveness: Estimate      GE.EST
# 234         Government Effectiveness: Number of Sources   GE.NO.SRC
# 235            Government Effectiveness: Standard Error  GE.STD.ERR
# 236   Political Stability and Absence of Violence/Te...      PV.EST
# 237   Political Stability and Absence of Violence/Te...   PV.NO.SRC
# 238   Political Stability and Absence of Violence/Te...  PV.STD.ERR
# 239                        Regulatory Quality: Estimate      RQ.EST
# 240               Regulatory Quality: Number of Sources   RQ.NO.SRC
# 241                  Regulatory Quality: Standard Error  RQ.STD.ERR
# 242                               Rule of Law: Estimate      RL.EST
# 243                      Rule of Law: Number of Sources   RL.NO.SRC
# 244                         Rule of Law: Standard Error  RL.STD.ERR
# 245                  Voice and Accountability: Estimate      VA.EST
# 246         Voice and Accountability: Number of Sources   VA.NO.SRC
# 247            Voice and Accountability: Standard Error  VA.STD.ERR
# 4893                    Control of Corruption: Estimate      CC.EST
# 4894                    Control of Corruption: Estimate      CC.EST
#
#       1996 [YR1996]  2000 [YR2000]  2004 [YR2004]  2008 [YR2008]  \
# 230        1.170964       1.199219       1.165965       1.276775
# 231        1.000000       1.000000       1.000000       1.000000
# 232        0.534351       0.512948       0.393849       0.401245
# 233        1.207623       1.191544       1.280985       1.270425
# 234        1.000000       1.000000       1.000000       1.000000
# 235        0.187618       0.331546       0.410163       0.451419
# 236        1.118007       1.107984       0.993218       1.316396
# 237        1.200000       1.200000       1.000000       2.000000
# 238        0.500303       0.514213       0.425198       0.332147
# 239        0.862141       0.922488       0.762954       0.894702
# 240        1.000000       1.000000       1.000000       1.000000
# 241        0.380820       0.406538       0.319958       0.381994
# 242        0.877413       0.924886       0.915527       0.847226
# 243        1.805025       1.995025       1.000000       1.000000
# 244        0.408408       0.320608       0.347726       0.357337
# 245        0.857999       0.879997       0.737521       0.967198
# 246        1.199369       1.212006       1.000000       1.000000
# 247        0.377748       0.431984       0.338822       0.511172
# 4893      25.653753      25.739173      25.957959      26.271420
# 4894      25.653753      25.739173      25.957959      26.271420
#
#       2012 [YR2012]  2016 [YR2016]  2020 [YR2020]
# 230        1.095236       1.280407       1.232362
# 231        2.000000       2.000000       2.000000
# 232        0.313170       0.307326       0.263738
# 233        1.247286       0.888866       1.121368
# 234        2.000000       2.000000       2.000000
# 235        0.313135       0.319699       0.357594
# 236        1.263882       1.284199       1.390273
# 237        3.000000       3.000000       3.000000
# 238        0.267992       0.244329       0.270814
# 239        1.402131       1.344240       0.925701
# 240        2.000000       2.000000       2.000000
# 241        0.342293       0.359897       0.374927
# 242        1.309788       1.253775       1.298945
# 243        3.000000       3.000000       3.000000
# 244        0.227907       0.247329       0.190690
# 245        1.284650       1.279364       1.286165
# 246        2.000000       1.000000       1.000000
# 247        0.209523       0.291437       0.263636
# 4893      26.443716      26.301871      26.114823
# 4894      26.443716      26.301871      26.114823

# %%
df_governance.head(20)
# Out:
#    Country Name Country Code  \
# 0   Afghanistan          AFG
# 1   Afghanistan          AFG
# 2   Afghanistan          AFG
# 3   Afghanistan          AFG
# 4   Afghanistan          AFG
# 5   Afghanistan          AFG
# 6   Afghanistan          AFG
# 7   Afghanistan          AFG
# 8   Afghanistan          AFG
# 9   Afghanistan          AFG
# 10  Afghanistan          AFG
# 11  Afghanistan          AFG
# 12  Afghanistan          AFG
# 13  Afghanistan          AFG
# 14  Afghanistan          AFG
# 15  Afghanistan          AFG
# 16  Afghanistan          AFG
# 17  Afghanistan          AFG
# 18  Afghanistan          AFG
# 19  Afghanistan          AFG
#
#                                           Series Name       Series Code  \
# 0                     Control of Corruption: Estimate            CC.EST
# 1            Control of Corruption: Number of Sources         CC.NO.SRC
# 2              Control of Corruption: Percentile Rank        CC.PER.RNK
# 3   Control of Corruption: Percentile Rank, Lower ...  CC.PER.RNK.LOWER
# 4   Control of Corruption: Percentile Rank, Upper ...  CC.PER.RNK.UPPER
# 5               Control of Corruption: Standard Error        CC.STD.ERR
# 6                  Government Effectiveness: Estimate            GE.EST
# 7         Government Effectiveness: Number of Sources         GE.NO.SRC
# 8           Government Effectiveness: Percentile Rank        GE.PER.RNK
# 9   Government Effectiveness: Percentile Rank, Low...  GE.PER.RNK.LOWER
# 10  Government Effectiveness: Percentile Rank, Upp...  GE.PER.RNK.UPPER
# 11           Government Effectiveness: Standard Error        GE.STD.ERR
# 12  Political Stability and Absence of Violence/Te...            PV.EST
# 13  Political Stability and Absence of Violence/Te...         PV.NO.SRC
# 14  Political Stability and Absence of Violence/Te...        PV.PER.RNK
# 15  Political Stability and Absence of Violence/Te...  PV.PER.RNK.LOWER
# 16  Political Stability and Absence of Violence/Te...  PV.PER.RNK.UPPER
# 17  Political Stability and Absence of Violence/Te...        PV.STD.ERR
# 18                       Regulatory Quality: Estimate            RQ.EST
# 19              Regulatory Quality: Number of Sources         RQ.NO.SRC
#
#     1996 [YR1996]  2000 [YR2000]  2004 [YR2004]  2008 [YR2008]  2012 [YR2012]  \
# 0       -1.291705      -1.271724      -1.350647      -1.672096      -1.430373
# 1        2.000000       2.000000       5.000000       7.000000      10.000000
# 2        4.301075       4.787234       6.403941       0.485437       1.421801
# 3        0.000000       0.000000       0.000000       0.000000       0.000000
# 4       27.419355      30.851065      15.270936       4.368932      11.848341
# 5        0.340507       0.346906       0.213201       0.224345       0.186088
# 6       -2.175167      -2.173946      -0.909889      -1.533435      -1.376419
# 7        1.000000       1.000000       4.000000       6.000000       8.000000
# 8        0.000000       0.000000      18.905472       3.398058       5.687204
# 9        0.000000       0.000000       5.970149       0.485437       0.473934
# 10       1.639344       2.732240      38.308456      13.106796      15.639811
# 11       0.187618       0.331546       0.238530       0.278415       0.227971
# 12      -2.417310      -2.438969      -2.295682      -2.691361      -2.418561
# 13       2.000000       2.000000       4.000000       3.000000       5.000000
# 14       2.127660       0.529101       1.941748       0.480769       1.895735
# 15       0.000000       0.000000       0.485437       0.000000       0.000000
# 16       6.914894       5.820106       4.368932       1.923077       3.791469
# 17       0.474807       0.453906       0.304598       0.309818       0.243882
# 18      -2.090330      -2.080253      -1.511549      -1.607167      -1.192580
# 19       1.000000       1.000000       4.000000       5.000000       8.000000
#
#     2016 [YR2016]  2020 [YR2020]
# 0       -1.534049      -1.480538
# 1       10.000000       9.000000
# 2        3.846154       4.807693
# 3        0.000000       0.000000
# 4        9.615385      10.576923
# 5        0.164448       0.157702
# 6       -1.254182      -1.585145
# 7        8.000000       7.000000
# 8        8.173077       5.288462
# 9        4.807693       1.442308
# 10      18.750000      12.019231
# 11       0.227726       0.276943
# 12      -2.671054      -2.705030
# 13       6.000000       5.000000
# 14       0.952381       0.471698
# 15       0.000000       0.000000
# 16       3.333333       2.358490
# 17       0.219708       0.245315
# 18      -1.336582      -1.402761
# 19       9.000000       8.000000

# %%
df_governance.dropna(inplace=True)

#drop irrelevant columns
df_governance.drop(columns=['Country Name', 'Series Name'], inplace=True)
df_governance.rename(columns={'1996 [YR1996]': '1996', '2000 [YR2000]': '2000', '2004 [YR2004]':'2004', '2008 [YR2008]':'2008', '2012 [YR2012]':'2012', '2016 [YR2016]':'2016', '2020 [YR2020]':'2020'}, inplace=True)


df_governance = pd.melt(df_governance, id_vars=['Country Code', 'Series Code'], value_vars=['1996', '2000', '2004', '2008', '2012', '2016', '2020'], var_name='year', value_name='value')
df_governance['year']=df_governance['year'].astype(int)

#remove all indicators that are not estimate values
df_governance.drop(df_governance[~df_governance['Series Code'].str.contains("EST", case=False)].index, inplace=True)


aaaa = df_governance.groupby(['Country Code', 'year', 'Series Code'], as_index = False).count()
aaaa = aaaa[aaaa.value>1]

for cc in set(aaaa["Country Code"].tolist()):
  df_governance = df_governance[df_governance["Country Code"] != cc]


df_governance = df_governance.pivot(index=['Country Code', 'year'], columns= 'Series Code',values="value")

df_governance.reset_index(inplace=True)

df_governance.columns = df_governance.columns.str.rstrip('.EST')

# %%
df_governance
# Out:
# Series Code Country Code  year        CC         G        PV        RL  \
# 0                    AFG  1996 -1.291705 -2.175167 -2.417310 -1.788075
# 1                    AFG  2000 -1.271724 -2.173946 -2.438969 -1.780661
# 2                    AFG  2004 -1.350647 -0.909889 -2.295682 -1.693925
# 3                    AFG  2008 -1.672096 -1.533435 -2.691361 -1.903308
# 4                    AFG  2012 -1.430373 -1.376419 -2.418561 -1.651893
# ...                  ...   ...       ...       ...       ...       ...
# 1486                 ZWE  2004 -1.253563 -1.001513 -1.204704 -1.688897
# 1487                 ZWE  2008 -1.348838 -1.542653 -1.212338 -1.791505
# 1488                 ZWE  2012 -1.381803 -1.375217 -0.778662 -1.630184
# 1489                 ZWE  2016 -1.271258 -1.209890 -0.619938 -1.381370
# 1490                 ZWE  2020 -1.289440 -1.299779 -1.072147 -1.307897
#
# Series Code        RQ        VA
# 0           -2.090330 -1.908540
# 1           -2.080253 -2.031417
# 2           -1.511549 -1.203034
# 3           -1.607167 -1.168902
# 4           -1.192580 -1.267430
# ...               ...       ...
# 1486        -1.974932 -1.553577
# 1487        -2.064896 -1.549031
# 1488        -1.871891 -1.471968
# 1489        -1.684896 -1.178460
# 1490        -1.416232 -1.113716
#
# [1491 rows x 8 columns]

# %% [markdown]
# # Store the dataframe

# %%
con.execute("DROP TABLE IF EXISTS Governance_Data;")
con.execute("CREATE TABLE IF NOT EXISTS Governance_Data AS SELECT * FROM df_governance")

# %% [markdown]
# close connection

# %%
con.close()
